# %%
import requests
import pandas as pd


url = 'https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json'
response = requests.get(url)
stations = pd.DataFrame(response.json()['data']['stations'])

# %%
stations.head(3)
# Out:
#                             external_id legacy_id     rental_methods  \
# 0  e823318f-8406-4230-8072-1667f5de78d4       681  [KEY, CREDITCARD]
# 1  13c42471-96ab-441d-9a4c-bc57f7af6f9b       685  [KEY, CREDITCARD]
# 2  e976c0ab-bc21-42b3-a2c2-b90def6f54f4       677  [KEY, CREDITCARD]
#
#                              station_id station_type  has_kiosk  \
# 0  e823318f-8406-4230-8072-1667f5de78d4      classic       True
# 1  13c42471-96ab-441d-9a4c-bc57f7af6f9b      classic       True
# 2  e976c0ab-bc21-42b3-a2c2-b90def6f54f4      classic       True
#
#    electric_bike_surcharge_waiver        lat region_id  \
# 0                           False  38.953691       104
# 1                           False  38.944013       104
# 2                           False  38.966848       104
#
#    eightd_has_key_dispenser eightd_station_services short_name  \
# 0                     False                      []      32243
# 1                     False                      []      32246
# 2                     False                      []      32239
#
#                                          rental_uris  \
# 0  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 1  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
# 2  {'ios': 'https://dc.lft.to/lastmile_qr_scan', ...
#
#                                 name        lon  capacity
# 0     Reston Town Center Metro North -77.359717        19
# 1  Golf Course Sq and Golf Course Dr -77.353552        12
# 2       Becontree Ln & Goldenrain Ct -77.329282        12
